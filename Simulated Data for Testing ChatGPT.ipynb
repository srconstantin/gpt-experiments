# %%
randoms = [np.random.normal() for i in range(0, 100)]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import statsmodels.formula.api as smf

# %%
linear = [5.3 + 0.045 * i + 0.5* randoms[i] for i in range(0, 100)]

# %%
plt.scatter(range(0, 100), linear)

# %%
linear
# Out:
# [4.811488267861589,
#  5.287686636387763,
#  5.205324763311427,
#  5.503856245667592,
#  5.463646052693208,
#  5.371704847364647,
#  5.404519150183393,
#  5.474232512551379,
#  5.280259933530354,
#  5.6212340400661915,
#  6.505938542165652,
#  5.416124287621168,
#  5.886732449771934,
#  5.620613120508454,
#  5.652610693383293,
#  5.789723710302207,
#  5.775678180976761,
#  6.900143373564863,
#  6.255714832983451,
#  6.0369729409753905,
#  4.86576998063581,
#  6.695167700587706,
#  6.292976992079794,
#  6.206435058950778,
#  6.619261102436784,
#  7.251145427075771,
#  5.961884602478352,
#  6.20731829541014,
#  6.225498523323465,
#  6.718145961868451,
#  6.625273752475305,
#  5.815361022704383,
#  6.861517413736561,
#  7.758096271046396,
#  7.278169067553308,
#  8.04925910209027,
#  6.583146030087715,
#  6.442526818414675,
#  6.841640413576434,
#  6.313272827138668,
#  7.207319219149824,
#  8.122068205369862,
#  7.241548696676803,
#  7.221738795474293,
#  7.547169938937511,
# ...

# %%
#at this point I asked GPT-4 "Please continue the following vector for 10 more entries."

# %%
response = [10.376496134613826,
10.114107282039301,
10.58719625219834,
10.82356748115998,
10.349229848174111,
10.527698920846277,
11.001558052303622,
11.193318915406933,
11.042130525489169,
11.481079831528645]

# %%
plt.scatter(range(0, 100), linear, color = 'blue', label = 'Noisy Linear Data')
plt.scatter(range(100, 110), response, color = 'red', label = 'GPT-4 Completion')
plt.legend()

# %%
#this looks sort of right but much tighter and with a higher slope; let's try it again asking for a longer response

# %%
response2 = [10.455271736921017,
10.30831602559227,
10.578901197413838,
10.169425835013103,
10.946037678041573,
11.014728461297033,
10.781934955221883,
10.88212097614378,
11.236880473554066,
11.093584210110662,
11.377905284453829,
11.201458907438026,
11.52691472867032,
11.830139764573186,
11.965038127084512,
11.610529329562625,
12.03476481618638,
12.386948138394958,
12.107235872481753,
12.569802535218027]

# %%
plt.scatter(range(0, 100), linear, color = 'blue', label = 'Noisy Linear Data')
plt.scatter(range(100, 120), response2, color = 'red', label = 'GPT-4 Completion')
plt.legend()

# %%
coefficients = np.polyfit(range(100,120), response2, 1)

# %%
coefficients
# Out:
# array([ 0.11182668, -0.94112475])

# %%
fitted_line = np.poly1d(coefficients)

# %%
y_pred = fitted_line(range(100, 120))

# %%
diffs = [response2[i] - y_pred[i] for i in range(0, 20)]

# %%
np.var(diffs)
# Out:
# 0.03737895602146649

# %%
np.var(randoms)
# Out:
# 1.036204946162158

# %%
#ok so the predicted continuation here is way less random and has a notably different slope.

# %%
#let's try this again

# %%
randoms = [np.random.normal() for i in range(0, 100)]

# %%
linear = [7.3 -.068 * i + 0.4* randoms[i] for i in range(0, 100)]

# %%
plt.scatter(range(0, 100), linear)

# %%
linear
# Out:
# [7.041515713141141,
#  6.996638317338265,
#  6.714936764135617,
#  7.259262237178266,
#  6.868510692721015,
#  7.3777944754785985,
#  7.297394203619114,
#  6.744428987781352,
#  6.717088195577641,
#  6.063617197435715,
#  7.047451817066558,
#  5.9141013329578564,
#  6.880720976768301,
#  6.8820560946645,
#  6.855256023832849,
#  6.015673552986645,
#  5.997539216878356,
#  5.783244156562574,
#  5.71242020261366,
#  5.832486032920824,
#  5.91766487159032,
#  5.755983234588495,
#  6.231578215733568,
#  6.019213145663624,
#  6.017542107746404,
#  5.665598221689467,
#  5.616328555147366,
#  5.183261266039343,
#  5.352463341809571,
#  5.0084082806499435,
#  4.7302189813477735,
#  5.353695897705305,
#  5.042468907147317,
#  5.943564408976474,
#  4.876230026372831,
#  4.318865568759845,
#  5.110216506063726,
#  5.60705621794717,
#  4.9236436081540935,
#  4.832795075490181,
#  4.948355904235743,
#  4.488017987680653,
#  4.942448341697943,
#  4.297125468846775,
#  4.249248651618604,
# ...

# %%
response3 = [0.8354120141901241,
0.6821973835968516,
1.240529183201508,
0.29531887024332985,
0.39217845113265964,
1.0694612139281538,
0.5007224657887946,
0.14873999212963016,
0.9800723845645425,
0.251984130761986,
-0.13727149896075756,
0.42546909338004724,
0.35471101463983535,
0.7250195722966694,
0.11940325951826717,
0.5420747939247312,
-0.20857467577177923,
0.15347822505581634,
-0.023556198740986913,
0.06668924356828146]

# %%
responsegpt3 = [1.317591708968062,
2.967397728445429,
2.2546922159928585,
3.559016898475984,
2.4153366703679273,
1.9905049769211243,
3.126244472944731,
2.905066946461328,
2.4826648717638327,
2.527449985099892,
3.3352765239824633,
3.720942988511021,
3.462967315262444,
2.879361769155748,
2.143969168216801,
3.610539099484887,
2.811369766563775,
2.689429350865428,
2.520145808045411,
3.578768333658119]

# %%
plt.scatter(range(0, 100), linear, color = 'blue', label = 'Noisy Linear Data')
plt.scatter(range(100, 120), response3, color = 'red', label = 'GPT-4 Completion')
plt.legend()

# %%
#shit, that looks perfect

# %%
plt.scatter(range(0, 100), linear, color = 'blue', label = 'Noisy Linear Data')
plt.scatter(range(100, 120), responsegpt3, color = 'red', label = 'GPT-3 Completion')
plt.legend()

# %%
 np.polyfit(range(100,120), response3, 1)
# Out:
# array([-0.04196595,  5.01597472])

# %%
#a little off but not too bad

# %%
#one more time

# %%
randoms = [np.random.normal() for i in range(0, 100)]

# %%
linear = [2.5 +.075 * i + 0.4* randoms[i] for i in range(0, 100)]

# %%
linear
# Out:
# [1.699883514980101,
#  2.353104650190334,
#  2.2730604579270777,
#  2.387641949067041,
#  2.9542525405296054,
#  2.5648269041305354,
#  2.8104062601256308,
#  2.3167828172471565,
#  3.4928572574401957,
#  3.738024132746484,
#  3.6500086996556913,
#  3.122007404720432,
#  3.4938252315924228,
#  3.269123913920424,
#  3.1517846897120374,
#  3.940765188681721,
#  3.5189874513900428,
#  3.8650025114972117,
#  2.983029219407415,
#  3.9553398445469963,
#  4.2926310543813,
#  4.4791918814025005,
#  4.734101567922544,
#  4.22018682210897,
#  3.8095168595468882,
#  4.06159893016055,
#  4.506138713026586,
#  4.220124217526485,
#  5.618480353858205,
#  4.198660119681296,
#  4.445921303241859,
#  4.797126881052452,
#  4.827131390040681,
#  4.3300825394573215,
#  5.283599503011848,
#  4.873759105825782,
#  4.663989635052117,
#  5.228549266972069,
#  5.19578959523711,
#  5.414489826504038,
#  5.131065079055873,
#  5.933054364213952,
#  5.163744002120653,
#  5.566788431370524,
#  6.06084947140509,
# ...

# %%
response4 = [10.489375862617835,
10.737254186349738,
11.023948624938203,
11.298372065114438,
10.860174659710982,
11.455974218033419,
10.950841375107572,
11.236025711302938,
11.673045302975712,
11.879423617584296,
12.155369726389571,
12.451972350276721,
12.018937465879682,
12.607338124935052,
12.099842309865817,
12.384526576023942,
12.823562472641538,
13.029430877847315,
13.305876995665312,
13.601972312533149]

# %%
plt.scatter(range(0, 100), linear, color = 'blue', label = 'Noisy Linear Data')
plt.scatter(range(100, 120), response4, color = 'red', label = 'GPT-4 Completion')
plt.legend()

# %%
coefficients = np.polyfit(range(100,120), response4, 1)

# %%
coefficients
# Out:
# array([ 0.14541434, -4.01870735])

# %%
#similarly, tighter and different slope

# %%
randoms = [np.random.normal() for i in range(0, 100)]
linear = [1 +.1 * i + 0.4* randoms[i] for i in range(0, 100)]

# %%
linear
# Out:
# [0.5288421866809319,
#  1.6029369946375902,
#  0.6835283113448875,
#  0.6645734878992737,
#  1.3838358520283967,
#  1.7979559219137031,
#  1.6461273598519637,
#  1.574065595648157,
#  1.4564425692004588,
#  2.357435234942498,
#  1.886757119275491,
#  1.0187402760801798,
#  2.7266451795114697,
#  1.7751295864677776,
#  2.293047720674279,
#  1.6815263245129461,
#  1.9035367277372583,
#  3.284121668129216,
#  2.8697934298542656,
#  3.028131770349291,
#  3.317763322021925,
#  2.6487104158026242,
#  2.93231612500011,
#  4.221536916303012,
#  3.8339253981442725,
#  3.3825100276888684,
#  3.692985913557727,
#  3.688732057057672,
#  3.8025258753878113,
#  3.2860117322469207,
#  3.3921274393949985,
#  4.332096467763869,
#  4.0468440937093355,
#  4.028394766534733,
#  4.575324197087388,
#  4.007898114171726,
#  4.8469979529341165,
#  5.12148239382192,
#  5.911155739564825,
#  4.686722787709565,
#  4.733290580685347,
#  5.788866980111061,
#  5.466199246980029,
#  4.96003415679406,
# ...

# %%
response5 = [11.231452013486321,
11.904587653728126,
10.712859634161659,
12.25791837486205,
11.683245179953618,
12.41536272651984,
10.982103258357027,
12.81152345929833,
11.134692718011196,
13.218551671832917,
12.647392059652781,
13.003724185379092,
11.542893725419107,
13.46712192469881,
12.059382764368723,
13.891893517533761,
12.201654892357476,
14.235614210268159,
13.107835643467879,
14.579334903002548]

# %%
plt.scatter(range(0, 100), linear, color = 'blue', label = 'Noisy Linear Data')
plt.scatter(range(100, 120), response5, color = 'red', label = 'GPT-4 Completion')
plt.legend()

# %%
#now let's try another function

# %%
randoms = [np.random.normal() for i in range(0, 100)]

# %%
coeffs = np.random.normal(loc=0, scale=1, size=(1, 4))

# %%
coeffs
# Out:
# array([[-0.1208493 ,  0.22982518, -0.19324472, -0.51076698]])

# %%
quadratic = [coeffs[0][0]+ coeffs[0][1]*i + coeffs[0][2]*i**2 + coeffs[0][3]*randoms[i] for i in range(0, 100)]

# %%
quadratic
# Out:
# [-0.8115686877539713,
#  -0.13763177663689327,
#  -0.06612717317864347,
#  -1.3595602900647221,
#  -2.763266145099588,
#  -4.251276657939979,
#  -4.873180651741482,
#  -7.274440236428269,
#  -11.143204756639456,
#  -12.602596762489988,
#  -17.374934625037604,
#  -21.09845108734371,
#  -25.1464778631747,
#  -28.80234382322304,
#  -34.38554570906596,
#  -40.16298403379313,
#  -45.78656123013894,
#  -51.34352848376804,
#  -57.96111428632499,
#  -65.39787004460801,
#  -72.47368765461215,
#  -80.97479833860297,
#  -88.72393454750727,
#  -97.78052965852089,
#  -105.89143202879575,
#  -114.6358768606461,
#  -124.87864360119002,
#  -135.4356430018754,
#  -144.64053221802337,
#  -155.78848884890252,
#  -167.59571984286148,
#  -178.36446391341644,
#  -190.08071529457234,
#  -202.8061917176713,
#  -215.12502425256525,
#  -229.54897792270611,
#  -241.85874900505257,
#  -255.87820961777402,
#  -269.92746093439445,
#  -285.08837774640614,
#  -300.1621751152233,
#  -315.60896898331174,
# ...

# %%
coeffs[0][0]
# Out:
# -0.12084929645029033

# %%
response6 = [-1909.2480973021218,
-1948.4752547621533,
-1986.902370912657,
-2026.4514572126543,
-2066.563662934425,
-2106.0934326133994,
-2147.1801967584766,
-2188.005735713862,
-2229.447321109974,
-2271.573088265921,
-2313.395998821067,
-2356.066760493221,
-2398.7842539519086,
-2441.602775431792,
-2485.236651054907,
-2529.0598272306844,
-2573.461284993988,
-2617.924259530536,
-2663.139453336834,
-2708.3727552910497]

# %%
plt.scatter(range(0, 100), quadratic, color = 'blue', label = 'Noisy Quadratic Data')
plt.scatter(range(100, 120), response6, color = 'red', label = 'GPT-4 Completion')
plt.legend()

# %%
plt.scatter(range(100, 120), response6)

# %%
randoms = [np.random.normal() for i in range(0, 100)]
coeffs = np.random.normal(loc=0, scale=10, size=(1, 4))
quadratic = [coeffs[0][0]+ coeffs[0][1]*i + coeffs[0][2]*i**2 + coeffs[0][3]*randoms[i] for i in range(0, 100)]

# %%
quadratic
# Out:
# [-12.450411322554043,
#  21.39936118465959,
#  28.53039284768363,
#  71.84871924319697,
#  142.10192966747798,
#  166.24216772414974,
#  298.8526453240634,
#  327.674420378215,
#  380.1211741651469,
#  444.3086526082142,
#  586.7370352543443,
#  636.2126273595727,
#  813.8179096685541,
#  894.3207304608995,
#  1071.329234612547,
#  1208.6385312043749,
#  1349.0032433070378,
#  1502.0320622655756,
#  1669.1351965925498,
#  1841.7556702485524,
#  2029.6884562065936,
#  2241.0832758602664,
#  2453.8410295411636,
#  2669.3844610243414,
#  2872.9702252077086,
#  3097.1195567929353,
#  3371.6491216863906,
#  3567.6763219203613,
#  3862.0260931365915,
#  4130.480273731084,
#  4427.43112694861,
#  4684.367479376261,
#  4951.119284165541,
#  5285.219079322576,
#  5558.66159505521,
#  5862.209647129902,
#  6243.091648484557,
#  6584.877645446251,
#  6936.763336139626,
#  7294.017799040134,
#  7652.392369054623,
#  8036.559036717131,
#  8413.502167578206,
#  8798.332942969955,
# ...

# %%
response7 = [9290.19727480447,
9477.63851555881,
9667.047464095532,
9859.67279199731,
10054.5091310487,
10251.74683974008,
10450.834748576872,
10652.215758687297,
10855.819854618494,
11061.961176643442,
11270.429722344756,
11481.391604235325,
11694.579155388752,
11909.852128665277,
12127.457119552822,
12347.697402611023,
12569.94552808456,
12794.365227289978,
13021.04596424066,
13250.24075153219]

# %%
plt.scatter(range(0, 100), quadratic, color = 'blue', label = 'Noisy Quadratic Data')
plt.scatter(range(100, 120), response7, color = 'red', label = 'GPT-4 Completion')
plt.legend()

# %%
randoms = [np.random.normal() for i in range(0, 100)]
coeffs = np.random.normal(loc=0, scale=1, size=(1, 4))
quadratic = [coeffs[0][0]+ coeffs[0][1]*i + coeffs[0][2]*i**2 + 1000*coeffs[0][3]*randoms[i] for i in range(0, 100)]

# %%
quadratic
# Out:
# [124.427505626811,
#  -425.3131956907542,
#  -157.24039334805946,
#  -249.07613125854414,
#  -54.411015159225975,
#  98.59964804157993,
#  35.39104296199321,
#  -273.73284072158725,
#  -14.14394378503561,
#  -11.07737339795434,
#  127.82309193152187,
#  -272.41776494027806,
#  561.1208155605622,
#  559.1511520383294,
#  286.94937303946335,
#  -382.7282687823661,
#  -219.29074870376462,
#  -217.44810583906488,
#  5.037582104469038,
#  -44.11879175429641,
#  382.6340982204055,
#  143.7722003654003,
#  471.7857181036083,
#  500.4567462539276,
#  -144.95483917912804,
#  130.00717037538493,
#  442.636745193326,
#  190.31201356887078,
#  484.5293934402211,
#  431.9974778235943,
#  1100.4422740065695,
#  205.72267017736846,
#  -144.4251759818065,
#  672.9859337434393,
#  562.5880060449502,
#  547.9118117710475,
#  627.7904952279146,
#  662.7923612356249,
#  738.9392032454241,
#  -86.33894498554758,
#  271.8639640497794,
#  726.3053404249599,
#  567.7789320076482,
#  485.08092626158157,
# ...

# %%
response = [2756.908429563827,
2689.123546826211,
2892.3756297825426,
2810.759791247589,
2927.981421522758,
3054.21654709347,
3181.736183284997,
3245.603411924825,
3328.419678150723,
3415.372943771342,
3562.985479290835,
3621.4863589156324,
3773.701292198158,
3845.8925615949035,
3992.481746997163,
4078.224166543168,
4215.658791653806,
4310.471846180369,
4456.091293842719,
4592.732161984281]

# %%
responsegpt3 = [124.427505626811,
-425.3131956907542,
-157.24039334805946,
-249.07613125854414,
-54.411015159225975,
98.59964804157993,
35.39104296199321,
-273.73284072158725,
-14.14394378503561,
-11.07737339795434,
127.82309193152187,
-272.41776494027806,
561.1208155605622,
559.1511520383294,
286.94937303946335,
-382.7282687823661,
-219.29074870376462,
-217.44810583906488,
5.037582104469038,
-44.11879175429641,
382.6340982204055,
143.7722003654003,
471.7857181036083,
500.4567462539276,
-144.95483917912804,
130.00717037538493,
442.636745193326,
190.31201356887078,
484.5293934402211,
431.9974778235943,
1100.4422740065695,
205.72267017736846,
-144.4251759818065,
672.9859337434393,
562.5880060449502,
547.9118117710475,
627.7904952279146,
662.7923612356249,
738.9392032454241,
-86.33894498554758,
271.8639640497794,
726.3053404249599,
567.7789320076482,
485.08092626158157,
723.8229869746718,
579.849813706528,
407.23732733772033,
122.28427196273793,
472.0450787606525,
493.6639596737654,
720.3253556537503,
495.14118608437275,
1116.3055185085823,
1230.979508971715,
1217.168091041799,
1090.8770530296133,
593.6495407095911,
705.0216124183086,
1143.4669671436825,
1061.1034286375393,
821.4739574572529,
367.5125668109206,
1359.043682389985,
1090.8974878554475,
789.7899407287927,
1625.4109488050326,
983.4398576998938,
407.857986299416,
1059.8281268188018,
1466.074158759765,
1271.3134522434686,
789.2221246168397,
1335.2718715144017,
850.60909210452,
1600.667172926836,
1404.8208654079126,
1479.0789494418525,
1430.9811169639565,
1475.2203072223565,
1460.581699663515,
1551.214393917193,
1619.6307120210488,
1491.8583244571691,
1574.8838661565703]

# %%
len(responsegpt3)
# Out:
# 84

# %%
plt.scatter(range(0, 100), quadratic, color = 'blue', label = 'Noisy Quadratic Data')
plt.scatter(range(100, 120), response, color = 'red', label = 'GPT-4 Completion')
plt.legend()

# %%
#lower variance but looks pretty much right

# %%
plt.scatter(range(0, 100), quadratic, color = 'blue', label = 'Noisy Quadratic Data')
plt.scatter(range(100, 184), responsegpt3, color = 'red', label = 'GPT-3 Completion')
plt.legend()

# %%
np.polyfit(range(100, 120), response, 2)
# Out:
# array([ 1.7678350e+00, -2.8650347e+02,  1.3654177e+04])

# %%
coeffs
# Out:
# array([[ 1.18352029, -1.56175203,  0.28777599, -0.06372598]])

# %%
#pretty far off

# %%
plt.plot([1.7678350e+00*x**2 + -2.8650347e+02*x + 1.3654177e+04 for x in range(0, 200)], color = 'blue', label = 'GPT4 best fit')
plt.plot([coeffs[0][0] + coeffs[0][1]*x + coeffs[0][2]*x**2 for x in range(0, 200)], color = 'red', label = 'non-noisy simulated data')
plt.legend()

# %%
plt.plot([1.7678350e+00*x**2 + -2.8650347e+02*x + 1.3654177e+04 for x in range(0, 120)], color = 'blue', label = 'GPT4 best fit')
plt.plot([coeffs[0][0] + coeffs[0][1]*x + coeffs[0][2]*x**2 for x in range(0, 120)], color = 'red', label = 'non-noisy simulated data')
plt.legend()

# %%
weights = np.polyfit(range(100, 120), response, 2)
model = np.poly1d(weights)
df = pd.DataFrame(columns=['y', 'x'])
df['y'] = response
df['x'] = range(100, 120)
results = smf.ols(formula='y ~ model(x) - 1', data=df).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          1.647e+05
# Date:                Thu, 20 Apr 2023   Prob (F-statistic):                    7.02e-39
# Time:                        12:11:56   Log-Likelihood:                         -101.40
# No. Observations:                  20   AIC:                                      204.8
# Df Residuals:                      19   BIC:                                      205.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
weights
# Out:
# array([ 1.7678350e+00, -2.8650347e+02,  1.3654177e+04])

# %%
weights = np.polyfit(range(0, 100), quadratic, 2)
model = np.poly1d(weights)
df = pd.DataFrame(columns=['y', 'x'])
df['y'] = quadratic
df['x'] = range(0, 100)
results = smf.ols(formula='y ~ model(x) - 1', data=df).fit()

# %%
weights
# Out:
# array([  0.2093511 ,   3.83252621, -24.24873581])

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.934
# Model:                            OLS   Adj. R-squared (uncentered):              0.933
# Method:                 Least Squares   F-statistic:                              1396.
# Date:                Thu, 20 Apr 2023   Prob (F-statistic):                    3.57e-60
# Time:                        12:11:39   Log-Likelihood:                         -711.67
# No. Observations:                 100   AIC:                                      1425.
# Df Residuals:                      99   BIC:                                      1428.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#cool this is useless

# %%
randoms = [np.random.normal() for i in range(0, 100)]

sine = [10*np.sin(0.1 *i) + randoms[i] for i in range(0, 100)]
plt.scatter(range(0, 100), sine, color = 'blue', label = 'Noisy Sine Data')

# %%
sine
# Out:
# [-0.3039965380680949,
#  0.5221741892632099,
#  2.3002455118309237,
#  2.8682458253445806,
#  4.458253229368722,
#  3.105506088409018,
#  5.615717737520953,
#  5.583288079992064,
#  7.6161595605625525,
#  6.539680525798569,
#  7.373504530846191,
#  9.811621849909445,
#  9.341386821764107,
#  10.24691734707413,
#  7.927755340623589,
#  9.68215648808196,
#  8.808945124520733,
#  8.819047454055989,
#  10.077280030641282,
#  9.64980200031159,
#  10.519184295296077,
#  9.67804615642452,
#  9.460126250315598,
#  5.201551365415203,
#  7.609737679053247,
#  6.210997392024498,
#  5.396220202457571,
#  3.7970869183106934,
#  3.418869040516562,
#  3.169585461741717,
#  2.7272375881692827,
#  -0.04780947370325722,
#  1.8932511774428762,
#  -1.2344492549062462,
#  -2.2205449702482696,
#  -5.098832436719038,
#  -4.869171776884242,
#  -4.6328909710272175,
#  -5.244549118466783,
#  -6.248335761395868,
#  -6.837529544351153,
#  -7.886727270232546,
#  -8.595269512819907,
#  -8.909827469999552,
# ...

# %%
response = [-5.667739283107542,
-6.980620032582631,
-6.272193848264301,
-7.33942671521625,
-8.931279592788402,
-9.218604720222107,
-10.327851889193731,
-11.01597484176891,
-12.152539638142316,
-12.94783650793842,
-11.583827439021711,
-11.22897366324392,
-10.819161785388186,
-9.523080881669245,
-8.6723929184162,
-7.475425738236201,
-6.859837450715457,
-5.099732546354199,
-4.37230179812251,
-3.8981271954937684]

# %%
responsegpt3 = [6.395769890335926,
7.926044777246578,
9.09034191887561,
8.28310677679012,
9.630481155678732,
8.725995638208205,
10.243583475633222,
10.417901567850057,
11.248299058312788,
10.719671867931905,
11.467929657838931,
12.361398812893622,
11.760904377950195,
12.528668594737488,
11.24804223104593,
12.364900172466829,
12.080323618489512,
12.759924016163632,
12.165688207401653,
12.736971307871703]

# %%
plt.scatter(range(0, 100), sine, color = 'blue', label = 'Noisy Sine Data')
plt.scatter(range(100, 120), response, color = 'red', label = 'GPT-4 Completion')
plt.legend()

# %%
plt.scatter(range(0, 100), sine, color = 'blue', label = 'Noisy Sine Data')
plt.scatter(range(100, 120), responsegpt3, color = 'red', label = 'GPT-3 Completion')
plt.legend()

# %%
randoms = [np.random.normal() for i in range(0, 100)]

dampedsine = [np.math.exp(0.05*i)*np.sin(0.5* i) + 2* randoms[i] for i in range(0, 100)]
plt.scatter(range(0, 100), sine, color = 'blue', label = 'Noisy Sine Data')

# %%
dampedsine
# Out:
# [-1.1770943109431493,
#  -0.8286882867196592,
#  1.6537357770486403,
#  0.3419908523002235,
#  0.49662203332967936,
#  -1.1307160413381503,
#  -0.7882273553743246,
#  -4.557897553281627,
#  -1.2406595606269641,
#  -3.0371231389621487,
#  -3.3657802916924346,
#  -1.0764237714060583,
#  4.054110448161236,
#  4.262066754748689,
#  -0.2153247532457483,
#  1.5763493261874433,
#  0.07101173032662755,
#  -1.2840228139790215,
#  1.1117834815807601,
#  -2.4542802854065244,
#  -0.7451313737906393,
#  -1.2493502007785446,
#  -3.6097587949524033,
#  -1.0651408299217575,
#  -1.289315974578575,
#  2.298840356987447,
#  -0.5242980906471961,
#  3.116747269054673,
#  3.8090376201281253,
#  2.709439718607265,
#  0.7706073858188542,
#  3.176380896988089,
#  -4.166849491026267,
#  -4.539506518805303,
#  -4.407170631095585,
#  -5.920788591088184,
#  -6.270210463746073,
#  -3.719210241867487,
#  1.364909491619894,
#  3.0890961909203183,
#  11.399853809702046,
#  7.714230677372475,
#  10.582674000812418,
# ...

# %%
response = [-55.28591562538371,
-2.6314870097593135,
31.094537382214364,
67.84847391326422,
106.11368411861537,
125.09247098014262,
95.3443276016537,
50.11785201407347,
-12.195351108213854,
-72.3289461335281,
-125.04613873125633,
-158.372987361697,
-158.1754662156783,
-120.79431607052832,
-50.83576073297226,
17.04962308782192,
87.23112053773156,
139.21758302406474,
159.67493642973954,
134.7652195230487]

# %%
plt.scatter(range(0, 100), dampedsine, color = 'blue', label = 'Noisy Damped Sine Data')
plt.scatter(range(100, 120), response, color = 'red', label = 'GPT-4 Completion')
plt.legend()

# %%
responsegpt3 = [-62.799270428787684,
-48.509930585728074,
-27.134937719835914,
-6.124017630706961,
14.451287274831537,
32.731800891238264,
52.93538848133893,
62.17384640589967,
79.49180386751242,
92.06872334007768,
94.78530681971058,
84.01482065429275,
72.07135602429828,
49.22789787124319,
35.51732764108768,
8.448284772026455,
-23.420013830877514,
-55.46963261476605,
-80.17312924685729,
-110.00462603846231]

# %%
plt.scatter(range(0, 100), dampedsine, color = 'blue', label = 'Noisy Damped Sine Data')
plt.scatter(range(100, 120), responsegpt3, color = 'red', label = 'GPT-3 Completion')
plt.legend()
